# %%
import churn_library as cl
import joblib

# %%
data= cl.import_data('data/bank_data.csv')

# %%
data.Churn
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10122    0
# 10123    1
# 10124    1
# 10125    1
# 10126    1
# Name: Churn, Length: 10127, dtype: int64

# %%
cl.perform_eda(data)
# Out:
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
cat_columns = [
    'Gender',
    'Education_Level',
    'Marital_Status',
    'Income_Category',
    'Card_Category'                
]

# %%
data = cl.encoder_helper(data, cat_columns, None)
# Out:
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# ...

# %%
x_train, x_test, y_train, y_test =cl.perform_feature_engineering(data, None)

# %%
rfc_model = joblib.load('./models/rfc_model.pkl')
lr_model = joblib.load('./models/logistic_model.pkl')

# %%
cl.feature_importance_plot(lr_model, x_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_45562/2952359487.py in <module>
# ----> 1 cl.feature_importance_plot(lr_model, x_train)
#
# ~/Documents/MlOps NanoDegree/Predict-Customer-Churn/churn_library.py in feature_importance_plot(model, X_data)
#     164              None
#     165     '''
# --> 166     importances = model.best_estimator_.feature_importances_
#     167     indices = np.argsort(importances)[::-1]
#     168     names = [X_data.columns[i] for i in indices]
#
# AttributeError: 'LogisticRegression' object has no attribute 'best_estimator_'

# %%
rfc_model.best
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=100, n_estimators=200,
#                        random_state=42)
